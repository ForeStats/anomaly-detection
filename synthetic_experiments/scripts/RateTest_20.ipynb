# %%
from sklearn.datasets import make_classification
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import train_test_split
from sklearn.metrics import PrecisionRecallDisplay, confusion_matrix

# Import models
from tensorflow import keras
from keras import models, layers, activations, losses, optimizers, metrics
from keras.callbacks import EarlyStopping
from keras.utils import plot_model

keras.utils.set_random_seed(42)
# Out:
# 2023-10-24 21:51:23.062285: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X,y = make_classification(n_samples=10000, n_features=16, n_informative=8,
                          n_redundant=8,
                          n_classes=2, n_clusters_per_class=2, class_sep=1.5, 
                          flip_y=0, weights=[0.8, 0.2], random_state=1)

# %%
X_scaled = MinMaxScaler().fit_transform(X) 
X_scaled = pd.DataFrame(X_scaled)
X_scaled.describe().T
# Out:
#       count      mean       std  min       25%       50%       75%  max
# 0   10000.0  0.415614  0.104518  0.0  0.345011  0.411832  0.482175  1.0
# 1   10000.0  0.421109  0.114669  0.0  0.341835  0.417185  0.495596  1.0
# 2   10000.0  0.382029  0.130635  0.0  0.291296  0.363626  0.456979  1.0
# 3   10000.0  0.529894  0.136774  0.0  0.445601  0.536535  0.621837  1.0
# 4   10000.0  0.552584  0.131236  0.0  0.469273  0.558022  0.640850  1.0
# 5   10000.0  0.495500  0.143019  0.0  0.400032  0.493938  0.590536  1.0
# 6   10000.0  0.436017  0.133470  0.0  0.344750  0.425791  0.516179  1.0
# 7   10000.0  0.468495  0.140453  0.0  0.367729  0.460670  0.566103  1.0
# 8   10000.0  0.565097  0.122046  0.0  0.493749  0.576476  0.648916  1.0
# 9   10000.0  0.516229  0.155956  0.0  0.397700  0.514477  0.633046  1.0
# 10  10000.0  0.501401  0.138344  0.0  0.397714  0.487322  0.602791  1.0
# 11  10000.0  0.497714  0.140236  0.0  0.397227  0.493101  0.595206  1.0
# 12  10000.0  0.573029  0.114778  0.0  0.501793  0.590010  0.652732  1.0
# 13  10000.0  0.507378  0.129099  0.0  0.416485  0.508191  0.598936  1.0
# 14  10000.0  0.485214  0.124120  0.0  0.403758  0.484949  0.566227  1.0
# 15  10000.0  0.524930  0.131786  0.0  0.434387  0.519683  0.617868  1.0

# %%
pca = PCA(n_components=8)
pca.fit(X_scaled)
print(np.sum(pca.explained_variance_ratio_))
pca_X = pca.fit_transform(X_scaled)

pca_df = pd.DataFrame(pca_X)
pca_df['is_anomaly'] = y
pca_df = pca_df.sort_values(by=['is_anomaly'])
# Out:
# 1.0000000000000004

# %%
plot_df = pca_df.copy()

corr = plot_df.corr()

plt.figure(figsize=(15,12))

sns.heatmap(corr)

plt.show()

# %%
plot_df = plot_df.iloc[:,[0, 3, 8]]
plot_df.columns = ["component_1", "component_2", "is_anomaly"]

# Scatter plot of 2 features
sns.jointplot(data = plot_df, x="component_1", y="component_2", hue = "is_anomaly", kind='scatter')

# %%
all_data = pd.DataFrame(X_scaled)
all_data['is_anomaly'] = y

X = all_data.drop(['is_anomaly'], axis = 1)
y = all_data['is_anomaly']
display(all_data)
# Out:
#              0         1         2         3         4         5         6
# 0     0.470176  0.405450  0.593196  0.435651  0.672981  0.279364  0.299375  \
# 1     0.377430  0.319853  0.212460  0.556318  0.416597  0.783454  0.696030
# 2     0.436690  0.443980  0.309410  0.580912  0.365964  0.542439  0.422309
# 3     0.507103  0.362746  0.321652  0.470923  0.573033  0.474652  0.316416
# 4     0.431895  0.481452  0.456081  0.560770  0.598296  0.354646  0.435627
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.247939  0.479135  0.237849  0.563011  0.347123  0.669657  0.550620
# 9996  0.605072  0.463835  0.453464  0.267458  0.603464  0.608906  0.638708
# 9997  0.405282  0.443128  0.326708  0.517402  0.607711  0.433293  0.326029
# 9998  0.512601  0.282344  0.228789  0.604517  0.565385  0.641568  0.545316
# 9999  0.843824  0.525468  0.561918  0.131006  0.798452  0.468770  0.652501
#
#              7         8         9        10        11        12        13
# 0     0.666585  0.633211  0.630963  0.380595  0.355740  0.671178  0.475886  \
# 1     0.397769  0.377845  0.305364  0.481666  0.749049  0.541606  0.669586
# 2     0.412380  0.558971  0.382238  0.691194  0.479551  0.586210  0.551285
# 3     0.280416  0.458646  0.329995  0.787079  0.629678  0.486046  0.639609
# 4     0.683338  0.661973  0.508515  0.443695  0.337938  0.609601  0.417759
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.547353  0.467595  0.469009  0.406463  0.593803  0.651049  0.448887
# 9996  0.426775  0.548789  0.603783  0.612570  0.616262  0.375822  0.690430
# 9997  0.422759  0.566109  0.452033  0.584356  0.525342  0.537841  0.459894
# 9998  0.251965  0.574030  0.250610  0.608397  0.632864  0.451485  0.647734
# 9999  0.435234  0.731567  0.620561  0.772754  0.512803  0.181162  0.731363
#
#             14        15  is_anomaly
# 0     0.367691  0.532662           0
# 1     0.478493  0.697357           1
# 2     0.317863  0.684170           0
# 3     0.478381  0.495561           0
# 4     0.411614  0.519161           0
# ...        ...       ...         ...
# 9995  0.590426  0.623571           0
# 9996  0.472715  0.584040           1
# 9997  0.600851  0.382670           0
# 9998  0.374540  0.536281           0
# 9999  0.387561  0.465310           1
#
# [10000 rows x 17 columns]

# %%
# create a train/test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, 
                                                    random_state=42, stratify=all_data['is_anomaly'])

print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# is_anomaly
# 0    6400
# 1    1600
# Name: count, dtype: int64
# is_anomaly
# 0    1600
# 1     400
# Name: count, dtype: int64

# %%
clf_IF = IsolationForest(random_state=42).fit(X_train)

y_train_pred = clf_IF.predict(X_train) * -1
y_train_pred[y_train_pred == -1] = 0
confusion_matrix(y_train, y_train_pred)

y_test_pred = clf_IF.predict(X_test) * -1
y_test_pred[y_test_pred == -1] = 0
confusion_matrix(y_test, y_test_pred)

y_score = clf_IF.decision_function(X_test) * -1

display = PrecisionRecallDisplay.from_predictions(
    y_test, y_score, name="IsolationForest", plot_chance_level=True
)
_ = display.ax_.set_title("2-class Precision-Recall curve")

# %%
clf_RF = RandomForestClassifier(n_estimators = 100, max_depth = 7, random_state=42).fit(X_train, y_train)

y_test_pred = clf_RF.predict(X_test)
print(confusion_matrix(y_test, y_test_pred))

y_score = clf_RF.predict_proba(X_test)[:,1]

display = PrecisionRecallDisplay.from_predictions(
    y_test, y_score, name="RandomForest", plot_chance_level=True
)
_ = display.ax_.set_title("2-class Precision-Recall curve")
# Out:
# [[1579   21]
#  [  26  374]]

# %%
X_train_normals = X_train[y_train == 0]
X_train_normals.shape
# Out:
# (6400, 16)

# %%
n_features = 16

# model
encoder = models.Sequential(name='encoder')
encoder.add(layer=layers.Dense(units=16, activation='relu', input_shape=(n_features,)))
encoder.add(layers.Dropout(0.2))
encoder.add(layer=layers.Dense(units=8, activation='relu'))

decoder = models.Sequential(name='decoder')
decoder.add(layer=layers.Dense(units=8, activation='relu', input_shape=(8,)))
decoder.add(layers.Dropout(0.2))
decoder.add(layer=layers.Dense(units=16, activation='relu'))
decoder.add(layers.Dropout(0.2))
decoder.add(layer=layers.Dense(units=n_features, activation='sigmoid'))

autoencoder = models.Sequential([encoder, decoder])

autoencoder.compile(
    loss=losses.mean_squared_error,
    optimizer=optimizers.Adam(),
    metrics=[metrics.mean_squared_error])

autoencoder.save_weights('init.h5')

print(encoder.summary())
print(decoder.summary())
print(autoencoder.summary())
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                272
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 8)                 136
#
# =================================================================
# Total params: 408 (1.59 KB)
# Trainable params: 408 (1.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 8)                 72
#
#  dropout_1 (Dropout)         (None, 8)                 0
#
#  dense_3 (Dense)             (None, 16)                144
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 16)                272
#
# =================================================================
# Total params: 488 (1.91 KB)
# Trainable params: 488 (1.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Sequential)        (None, 8)                 408
#
#  decoder (Sequential)        (None, 16)                488
#
# =================================================================
# Total params: 896 (3.50 KB)
# Trainable params: 896 (3.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
autoencoder.load_weights('init.h5')

es = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, restore_best_weights=True)

history = autoencoder.fit(x=X_train_normals, y=X_train_normals, epochs=50, 
                      batch_size=32, shuffle=True, verbose=1, 
                      validation_data=(X_train_normals, X_train_normals), 
                      callbacks=[es])

predicted_test = autoencoder.predict(x=X_test)

y_score = losses.mean_squared_error(predicted_test, X_test)

display = PrecisionRecallDisplay.from_predictions(
    y_test, y_score, name="AutoEncoder", plot_chance_level=True
)
_ = display.ax_.set_title("Precision-Recall curve")
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1s 2ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 2/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 3/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 4/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 5/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 6/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 7/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 8/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 9/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 10/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 11/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 12/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 13/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 14/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 15/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 16/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 17/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 18/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 19/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 20/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 21/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 22/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 23/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 24/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 25/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 26/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 27/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 28/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 29/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 30/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 31/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 32/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# 63/63 [==============================] - 0s 638us/step

# %%
es = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, restore_best_weights=True)

n_vec = [1000, 1000, 1000]

for i in range(3):
    
    autoencoder.load_weights('init.h5')

    history = autoencoder.fit(x=X_train, y=X_train, epochs=50, 
                          batch_size=32, shuffle=True, verbose=1, 
                          validation_data=(X_train, X_train), 
                          callbacks=[es])
    
    predicted_test = autoencoder.predict(x=X_test)

    y_score = losses.mean_squared_error(predicted_test, X_test)

    display = PrecisionRecallDisplay.from_predictions(
        y_test, y_score, name="AutoEncoder", plot_chance_level=True
    )
    _ = display.ax_.set_title("Precision-Recall curve")
    
    predicted_train = autoencoder.predict(x=X_train)

    y_score = losses.mean_squared_error(predicted_train, X_train)
    
    y_train_pred = np.array([0] * len(y_train))
    y_train_pred[np.argsort(y_score)[-n_vec[i]:]] = 1
    print(confusion_matrix(y_train, y_train_pred))
    print(len(np.where((y_train == y_train_pred) & (y_train_pred == 1))[0]))
    print(len(np.where((y_train != y_train_pred) | (y_train_pred == 0))[0]))
    
    X_train = X_train.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    print(X_train.shape)
    retain_index = np.where((y_train != y_train_pred) | (y_train_pred == 0))[0]
    print(len(retain_index))
    X_train = X_train.iloc[retain_index, :]
    y_train = y_train[retain_index]
    print(X_train.shape)
    print(y_train.shape)
# Out:
# Epoch 1/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 2/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 3/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 4/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 5/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 6/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 7/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 8/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 9/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 10/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 11/50
# 250/250 [==============================] - 0s 1ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 12/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 13/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 14/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 15/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 16/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 17/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 18/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 19/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 20/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 21/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 22/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 23/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 24/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 25/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# 63/63 [==============================] - 0s 616us/step
# 250/250 [==============================] - 0s 669us/step
# [[5891  509]
#  [1109  491]]
# 491
# 7509
# (8000, 16)
# 7509
# (7509, 16)
# (7509,)
# Epoch 1/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 2/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 3/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 4/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 5/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 6/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 7/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 8/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 9/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 10/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 11/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 12/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 13/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 14/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 15/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 16/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 17/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 18/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 19/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 20/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 21/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 22/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 23/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 24/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 25/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 26/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 27/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 28/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 29/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 30/50
# 235/235 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# 63/63 [==============================] - 0s 624us/step
# 235/235 [==============================] - 0s 612us/step
# [[5716  684]
#  [ 793  316]]
# 316
# 7193
# (7509, 16)
# 7193
# (7193, 16)
# (7193,)
# Epoch 1/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 2/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 3/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 4/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 5/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 6/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 7/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 8/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 9/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 10/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 11/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 12/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 13/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 14/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 15/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 16/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 17/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 18/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 19/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 20/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 21/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 22/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 23/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 24/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 25/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 26/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 27/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 28/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 29/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 30/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 31/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 32/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 33/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 34/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 35/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 36/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# 63/63 [==============================] - 0s 612us/step
# 225/225 [==============================] - 0s 608us/step
# [[5565  835]
#  [ 628  165]]
# 165
# 7028
# (7193, 16)
# 7028
# (7028, 16)
# (7028,)

# %%
# create a train/test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, 
                                                    random_state=42, stratify=all_data['is_anomaly'])

print(y_train.value_counts())
print(y_test.value_counts())

X_train_normals = X_train[y_train == 0]
print(X_train_normals.shape)
# Out:
# is_anomaly
# 0    6400
# 1    1600
# Name: count, dtype: int64
# is_anomaly
# 0    1600
# 1     400
# Name: count, dtype: int64
# (6400, 16)

# %%
clf = OneClassSVM(gamma='scale', nu=0.2)

n_vec = [1000, 1000, 1000]

for i in range(3):

    clf.fit(X_train)
    
    y_score = clf.decision_function(X_test) * -1

    display = PrecisionRecallDisplay.from_predictions(
        y_test, y_score, name="OneClassSVM", plot_chance_level=True
    )
    _ = display.ax_.set_title("Precision-Recall curve")
    
    y_score = clf.decision_function(X_train) * -1
    
    y_train_pred = np.array([0] * len(y_train))
    y_train_pred[np.argsort(y_score)[-n_vec[i]:]] = 1
    print(confusion_matrix(y_train, y_train_pred))
    print(len(np.where((y_train == y_train_pred) & (y_train_pred == 1))[0]))
    print(len(np.where((y_train != y_train_pred) | (y_train_pred == 0))[0]))
    
    X_train = X_train.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    print(X_train.shape)
    retain_index = np.where((y_train != y_train_pred) | (y_train_pred == 0))[0]
    print(len(retain_index))
    X_train = X_train.iloc[retain_index, :]
    y_train = y_train[retain_index]
    print(X_train.shape)
    print(y_train.shape)
# Out:
# [[5807  593]
#  [1193  407]]
# 407
# 7593
# (8000, 16)
# 7593
# (7593, 16)
# (7593,)
# [[5642  758]
#  [ 951  242]]
# 242
# 7351
# (7593, 16)
# 7351
# (7351, 16)
# (7351,)
# [[5569  831]
#  [ 782  169]]
# 169
# 7182
# (7351, 16)
# 7182
# (7182, 16)
# (7182,)

# %%
clf.fit(X_train_normals)
    
y_score = clf.decision_function(X_test) * -1

display = PrecisionRecallDisplay.from_predictions(
    y_test, y_score, name="OneClassSVM", plot_chance_level=True
)
_ = display.ax_.set_title("Precision-Recall curve")

# %%
# create a train/test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, 
                                                    random_state=42, stratify=all_data['is_anomaly'])

print(y_train.value_counts())
print(y_test.value_counts())

X_train_normals = X_train[y_train == 0]
print(X_train_normals.shape)
# Out:
# is_anomaly
# 0    6400
# 1    1600
# Name: count, dtype: int64
# is_anomaly
# 0    1600
# 1     400
# Name: count, dtype: int64
# (6400, 16)

# %%
n_vec = [1000, 1000, 1000]

for i in range(3):
    
    pca = PCA(n_components=6, random_state=42)
    pca_train = pd.DataFrame(pca.fit_transform(X_train))
    pca_test = pd.DataFrame(pca.transform(X_test))
    
    predicted_test = pd.DataFrame(pca.inverse_transform(pca_test))

    y_score = losses.mean_squared_error(predicted_test, X_test)

    display = PrecisionRecallDisplay.from_predictions(
        y_test, y_score, name="PCA", plot_chance_level=True
    )
    _ = display.ax_.set_title("Precision-Recall curve")
    
    predicted_train = pd.DataFrame(pca.inverse_transform(pca_train))

    y_score = losses.mean_squared_error(predicted_train, X_train)
    
    y_train_pred = np.array([0] * len(y_train))
    y_train_pred[np.argsort(y_score)[-n_vec[i]:]] = 1
    print(confusion_matrix(y_train, y_train_pred))
    print(len(np.where((y_train == y_train_pred) & (y_train_pred == 1))[0]))
    print(len(np.where((y_train != y_train_pred) | (y_train_pred == 0))[0]))
    
    X_train = X_train.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    print(X_train.shape)
    retain_index = np.where((y_train != y_train_pred) | (y_train_pred == 0))[0]
    print(len(retain_index))
    X_train = X_train.iloc[retain_index, :]
    y_train = y_train[retain_index]
    print(X_train.shape)
    print(y_train.shape)
# Out:
# [[5960  440]
#  [1040  560]]
# 560
# 7440
# (8000, 16)
# 7440
# (7440, 16)
# (7440,)
# [[5676  724]
#  [ 764  276]]
# 276
# 7164
# (7440, 16)
# 7164
# (7164, 16)
# (7164,)
# [[5544  856]
#  [ 620  144]]
# 144
# 7020
# (7164, 16)
# 7020
# (7020, 16)
# (7020,)

# %%
pca = PCA(n_components=6, random_state=42)
pca_train = pd.DataFrame(pca.fit_transform(X_train_normals))
pca_test = pd.DataFrame(pca.transform(X_test))

predicted_test = pd.DataFrame(pca.inverse_transform(pca_test))

y_score = losses.mean_squared_error(predicted_test, X_test)

display = PrecisionRecallDisplay.from_predictions(
    y_test, y_score, name="PCA", plot_chance_level=True
)
_ = display.ax_.set_title("Precision-Recall curve")
